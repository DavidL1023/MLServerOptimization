# %% [markdown]
# <a href="https://colab.research.google.com/github/DavidL1023/MLServerOptimization/blob/Mason-model/prophet_w_cross_val_gridsearch.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Import necessary libraries
import pandas as pd
from prophet import Prophet
from prophet.plot import plot_cross_validation_metric
from prophet.diagnostics import cross_validation
from prophet.diagnostics import performance_metrics
import matplotlib.pyplot as plt
import itertools
import numpy as np

# %%
# Load the CSV file and adjust column names
file_path = 'aggregated2.csv'
data = pd.read_csv(file_path, header=None, names=['ds', 'y'])

# Convert the 'ds' column to datetime format
data['ds'] = pd.to_datetime(data['ds'])

# %%
# Prep parameters for grid search
param_grid = {
    'changepoint_prior_scale': [0.001, 0.01, 0.05, 0.1, 0.5],
    'seasonality_prior_scale': [0.01, 0.1, 0.5, 1.0, 10.0],
    # Limit the grid due to dataset size; avoid overcomplex models
}

all_params = [dict(zip(param_grid.keys(), v)) for v in itertools.product(*param_grid.values())]
mape_scores = []  # To store the MAPE scores for each parameter set

for params in all_params:
    # Initialize and fit the Prophet model with current parameters
    m = Prophet(**params)
    m.fit(data)

    # Perform cross-validation
    df_cv = cross_validation(m, initial='23 days', period='12 hours', horizon='6 hours')
    df_p = performance_metrics(df_cv)

    # Calculate and store the MAPE score
    mape = df_p['mape'].mean()
    mape_scores.append(mape)

# Identify the best performing set of parameters
best_score_index = np.argmin(mape_scores)
best_params = all_params[best_score_index]

print("Best Parameters:", best_params)
# Out:
# INFO:prophet:Disabling yearly seasonality. Run prophet with yearly_seasonality=True to override this.
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpymz0pe25/whcjr7lq.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpymz0pe25/srdwbtnt.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.10/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=49772', 'data', 'file=/tmp/tmpymz0pe25/whcjr7lq.json', 'init=/tmp/tmpymz0pe25/srdwbtnt.json', 'output', 'file=/tmp/tmpymz0pe25/prophet_modelizzw1ld6/prophet_model-20240306171022.csv', 'method=optimize', 'algorithm=lbfgs', 'iter=10000']
# 17:10:22 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 17:10:23 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# INFO:prophet:Making 15 forecasts with cutoffs between 2023-10-10 13:30:00 and 2023-10-17 13:30:00
#   0%|          | 0/15 [00:00<?, ?it/s]
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpymz0pe25/xzstmny9.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpymz0pe25/gbq_c2e9.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.10/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=87449', 'data', 'file=/tmp/tmpymz0pe25/xzstmny9.json', 'init=/tmp/tmpymz0pe25/gbq_c2e9.json', 'output', 'file=/tmp/tmpymz0pe25/prophet_modeloeeuj7es/prophet_model-20240306171023.csv', 'method=optimize', 'algorithm=lbfgs', 'iter=10000']
# 17:10:23 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 17:10:24 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpymz0pe25/0bdw6t8s.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpymz0pe25/v5kxzgal.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.10/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=90539', 'data', 'file=/tmp/tmpymz0pe25/0bdw6t8s.json', 'init=/tmp/tmpymz0pe25/v5kxzgal.json', 'output', 'file=/tmp/tmpymz0pe25/prophet_modelgdt2aicp/prophet_model-20240306171024.csv', 'method=optimize', 'algorithm=lbfgs', 'iter=10000']
# 17:10:24 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 17:10:24 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpymz0pe25/xs6a8jq9.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpymz0pe25/iixoeqpm.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.10/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=47818', 'data', 'file=/tmp/tmpymz0pe25/xs6a8jq9.json', 'init=/tmp/tmpymz0pe25/iixoeqpm.json', 'output', 'file=/tmp/tmpymz0pe25/prophet_modelu8c53vyg/prophet_model-20240306171025.csv', 'method=optimize', 'algorithm=lbfgs', 'iter=10000']
# 17:10:25 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 17:10:25 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpymz0pe25/4625ba2c.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpymz0pe25/wxrxqh8_.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.10/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=72684', 'data', 'file=/tmp/tmpymz0pe25/4625ba2c.json', 'init=/tmp/tmpymz0pe25/wxrxqh8_.json', 'output', 'file=/tmp/tmpymz0pe25/prophet_modelxfviljmi/prophet_model-20240306171026.csv', 'method=optimize', 'algorithm=lbfgs', 'iter=10000']
# 17:10:26 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 17:10:26 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpymz0pe25/n3vvqvl2.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpymz0pe25/na5jy7ln.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.10/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=78807', 'data', 'file=/tmp/tmpymz0pe25/n3vvqvl2.json', 'init=/tmp/tmpymz0pe25/na5jy7ln.json', 'output', 'file=/tmp/tmpymz0pe25/prophet_modelzzmzxbvs/prophet_model-20240306171027.csv', 'method=optimize', 'algorithm=lbfgs', 'iter=10000']
# 17:10:27 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 17:10:27 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpymz0pe25/duvooo3e.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpymz0pe25/_xppezgs.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.10/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=31529', 'data', 'file=/tmp/tmpymz0pe25/duvooo3e.json', 'init=/tmp/tmpymz0pe25/_xppezgs.json', 'output', 'file=/tmp/tmpymz0pe25/prophet_modelp9cqld7v/prophet_model-20240306171028.csv', 'method=optimize', 'algorithm=lbfgs', 'iter=10000']
# 17:10:28 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 17:10:28 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpymz0pe25/m1yi7qrg.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpymz0pe25/6lfybaj7.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.10/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=20733', 'data', 'file=/tmp/tmpymz0pe25/m1yi7qrg.json', 'init=/tmp/tmpymz0pe25/6lfybaj7.json', 'output', 'file=/tmp/tmpymz0pe25/prophet_modelebuxdpaz/prophet_model-20240306171028.csv', 'method=optimize', 'algorithm=lbfgs', 'iter=10000']
# 17:10:29 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 17:10:29 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpymz0pe25/slbl9uzf.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpymz0pe25/zod3l_2g.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.10/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=36059', 'data', 'file=/tmp/tmpymz0pe25/slbl9uzf.json', 'init=/tmp/tmpymz0pe25/zod3l_2g.json', 'output', 'file=/tmp/tmpymz0pe25/prophet_model22zj0tyt/prophet_model-20240306171029.csv', 'method=optimize', 'algorithm=lbfgs', 'iter=10000']
# 17:10:29 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 17:10:30 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpymz0pe25/tg_rtir5.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpymz0pe25/n9i788jh.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.10/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=
.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.10/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=9831', 'data', 'file=/tmp/tmpymz0pe25/g5wz0omh.json', 'init=/tmp/tmpymz0pe25/mgzk92tm.json', 'output', 'file=/tmp/tmpymz0pe25/prophet_modelsr4w34jk/prophet_model-20240306172401.csv', 'method=optimize', 'algorithm=lbfgs', 'iter=10000']
# 17:24:01 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 17:24:04 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpymz0pe25/2eju27sx.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpymz0pe25/_l_xyrgo.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.10/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=52224', 'data', 'file=/tmp/tmpymz0pe25/2eju27sx.json', 'init=/tmp/tmpymz0pe25/_l_xyrgo.json', 'output', 'file=/tmp/tmpymz0pe25/prophet_modelyjm7niof/prophet_model-20240306172404.csv', 'method=optimize', 'algorithm=lbfgs', 'iter=10000']
# 17:24:04 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 17:24:07 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpymz0pe25/jvsc8u0r.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpymz0pe25/9ds8v4k9.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.10/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=90837', 'data', 'file=/tmp/tmpymz0pe25/jvsc8u0r.json', 'init=/tmp/tmpymz0pe25/9ds8v4k9.json', 'output', 'file=/tmp/tmpymz0pe25/prophet_modelqn2pqpvz/prophet_model-20240306172407.csv', 'method=optimize', 'algorithm=lbfgs', 'iter=10000']
# 17:24:07 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 17:24:10 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpymz0pe25/wb23crta.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpymz0pe25/edpyy23h.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.10/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=61616', 'data', 'file=/tmp/tmpymz0pe25/wb23crta.json', 'init=/tmp/tmpymz0pe25/edpyy23h.json', 'output', 'file=/tmp/tmpymz0pe25/prophet_modelxkqu9uww/prophet_model-20240306172410.csv', 'method=optimize', 'algorithm=lbfgs', 'iter=10000']
# 17:24:10 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 17:24:13 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpymz0pe25/_edlmqwk.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpymz0pe25/1zci6qpe.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.10/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=1411', 'data', 'file=/tmp/tmpymz0pe25/_edlmqwk.json', 'init=/tmp/tmpymz0pe25/1zci6qpe.json', 'output', 'file=/tmp/tmpymz0pe25/prophet_modelt_2jxmv7/prophet_model-20240306172414.csv', 'method=optimize', 'algorithm=lbfgs', 'iter=10000']
# 17:24:14 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 17:24:17 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpymz0pe25/m2sa3mel.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpymz0pe25/k_av7dlm.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.10/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=40995', 'data', 'file=/tmp/tmpymz0pe25/m2sa3mel.json', 'init=/tmp/tmpymz0pe25/k_av7dlm.json', 'output', 'file=/tmp/tmpymz0pe25/prophet_modelyda5vcra/prophet_model-20240306172417.csv', 'method=optimize', 'algorithm=lbfgs', 'iter=10000']
# 17:24:17 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 17:24:20 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpymz0pe25/5qq29l7w.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpymz0pe25/x0wwrcz7.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.10/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=61952', 'data', 'file=/tmp/tmpymz0pe25/5qq29l7w.json', 'init=/tmp/tmpymz0pe25/x0wwrcz7.json', 'output', 'file=/tmp/tmpymz0pe25/prophet_modell7vlwmz0/prophet_model-20240306172420.csv', 'method=optimize', 'algorithm=lbfgs', 'iter=10000']
# 17:24:20 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 17:24:23 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpymz0pe25/kls1wc79.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpymz0pe25/0dmcdkzk.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.10/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=67233', 'data', 'file=/tmp/tmpymz0pe25/kls1wc79.json', 'init=/tmp/tmpymz0pe25/0dmcdkzk.json', 'output', 'file=/tmp/tmpymz0pe25/prophet_model0u4fch13/prophet_model-20240306172424.csv', 'method=optimize', 'algorithm=lbfgs', 'iter=10000']
# 17:24:24 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 17:24:26 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpymz0pe25/19lv1hum.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpymz0pe25/cws8ahr4.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.10/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=12714', 'data', 'file=/tmp/tmpymz0pe25/19lv1hum.json', 'init=/tmp/tmpymz0pe25/cws8ahr4.json', 'output', 'file=/tmp/tmpymz0pe25/prophet_modelpdymp7hb/prophet_model-20240306172427.csv', 'method=optimize', 'algorithm=lbfgs', 'iter=10000']
# 17:24:27 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 17:24:30 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpymz0pe25/v6gqzf4g.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpymz0pe25/wwj3d2sg.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.10/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=96104', 'data', 'file=/tmp/tmpymz0pe25/v6gqzf4g.json', 'init=/tmp/tmpymz0pe25/wwj3d2sg.json', 'output', 'file=/tmp/tmpymz0pe25/prophet_modelbmddp77k/prophet_model-20240306172430.csv', 'method=optimize', 'algorithm=lbfgs', 'iter=10000']
# 17:24:30 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 17:24:33 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpymz0pe25/wluc4_3p.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpymz0pe25/zmeryj7r.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.10/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=13788', 'data', 'file=/tmp/tmpymz0pe25/wluc4_3p.json', 'init=/tmp/tmpymz0pe25/zmeryj7r.json', 'output', 'file=/tmp/tmpymz0pe25/prophet_modelgnv3zy97/prophet_model-20240306172434.csv', 'method=optimize', 'algorithm=lbfgs', 'iter=10000']
# 17:24:34 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 17:24:37 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpymz0pe25/m5gfzwxy.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpymz0pe25/cybvgh1v.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.10/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=77433', 'data', 'file=/tmp/tmpymz0pe25/m5gfzwxy.json', 'init=/tmp/tmpymz0pe25/cybvgh1v.json', 'output', 'file=/tmp/tmpymz0pe25/prophet_modelkfjfhv9w/prophet_model-20240306172437.csv', 'method=optimize', 'algorithm=lbfgs', 'iter=10000']
# 17:24:37 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 17:24:41 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpymz0pe25/dh8a8kgo.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpymz0pe25/x19yq0kv.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.10/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=9972', 'data', 'file=/tmp/tmpymz0pe25/dh8a8kgo.json', 'init=/tmp/tmpymz0pe25/x19yq0kv.json', 'output', 'file=/tmp/tmpymz0pe25/prophet_modelfugno_wq/prophet_model-20240306172442.csv', 'method=optimize', 'algorithm=lbfgs', 'iter=10000']
# 17:24:42 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 17:24:45 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpymz0pe25/n4jv2te0.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpymz0pe25/dbkauoei.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.10/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=51604', 'data', 'file=/tmp/tmpymz0pe25/n4jv2te0.json', 'init=/tmp/tmpymz0pe25/dbkauoei.json', 'output', 'file=/tmp/tmpymz0pe25/prophet_model94d2ptyc/prophet_model-20240306172445.csv', 'method=optimize', 'algorithm=lbfgs', 'iter=10000']
# 17:24:45 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 17:24:48 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpymz0pe25/fww0pv7b.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpymz0pe25/cnzq_879.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.10/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=42760', 'data', 'file=/tmp/tmpymz0pe25/fww0pv7b.json', 'init=/tmp/tmpymz0pe25/cnzq_879.json', 'output', 'file=/tmp/tmpymz0pe25/prophet_modelltr3ea6g/prophet_model-20240306172448.csv', 'method=optimize', 'algorithm=lbfgs', 'iter=10000']
# 17:24:48 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 17:24:52 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# Best Parameters: {'changepoint_prior_scale': 0.001, 'seasonality_prior_scale': 0.01}
